# %%
import pandas as pd
import sqlalchemy
from datetime import datetime

# %%
engine_read_govt_stardb = sqlalchemy.create_engine('mysql+pymysql://manoj:cJtDsZ4UF6djRRXg@server12.agribazaar.com:3307/Stardb')
engine_read_govt = sqlalchemy.create_engine('mysql+pymysql://manoj:cJtDsZ4UF6djRRXg@server12.agribazaar.com:3307/nafed')
engine_read_govt_plogs = sqlalchemy.create_engine('mysql+pymysql://manoj:cJtDsZ4UF6djRRXg@server12.agribazaar.com:3307/plogs')

# %%
engine_write = sqlalchemy.create_engine('mysql+pymysql://manoj:cJtDsZ4UF6djRRXg@agri-reports.c2c32urb2pzx.ap-south-1.rds.amazonaws.com:3306/agri_reports')

# %%
# read data from nafed
df1 = pd.read_sql('abc_otp',engine_read_govt)
df2 = pd.read_sql('abc_users_groups',engine_read_govt)
df3 = pd.read_sql('abc_users_groups_map',engine_read_govt)
df4 = pd.read_sql('auction_multiple_docs',engine_read_govt)
df5 = pd.read_sql('client_logs',engine_read_govt)
df6 = pd.read_sql('countries',engine_read_govt)
df7 = pd.read_sql('icds_api_logs',engine_read_govt)
df8 = pd.read_sql('icds_center_master',engine_read_govt)
df9 = pd.read_sql('icds_delivery_report',engine_read_govt)
df10 = pd.read_sql('icds_primary_dispatch',engine_read_govt)
df11 = pd.read_sql('migrations',engine_read_govt)
df12 = pd.read_sql('milling_sms_text',engine_read_govt)
df13 = pd.read_sql('naf_areas',engine_read_govt)
df14 = pd.read_sql('naf_auc_stock_map',engine_read_govt)
df15 = pd.read_sql('naf_branch_users_map',engine_read_govt)
df16 = pd.read_sql('naf_branches',engine_read_govt)
df17 = pd.read_sql('naf_com_units',engine_read_govt)
df18 = pd.read_sql('naf_commodity_group',engine_read_govt)
df19 = pd.read_sql('naf_cron_locks',engine_read_govt)
df20 = pd.read_sql('naf_district_odr_map',engine_read_govt)
df21 = pd.read_sql('naf_do_raised',engine_read_govt)
df22 = pd.read_sql('naf_document_master',engine_read_govt)
df23 = pd.read_sql('naf_due_payments',engine_read_govt)
df24 = pd.read_sql('naf_itd_docs',engine_read_govt)
df25 = pd.read_sql('naf_itd_forms',engine_read_govt)
df26 = pd.read_sql('naf_miller',engine_read_govt)
df27 = pd.read_sql('naf_miller_copy',engine_read_govt)
df28 = pd.read_sql('naf_miller_docs_mapping',engine_read_govt)
df29 = pd.read_sql('naf_miller_plant_doc',engine_read_govt)
df30 = pd.read_sql('naf_miller_plant_info',engine_read_govt)
df31 = pd.read_sql('naf_miller_plants',engine_read_govt)
df32 = pd.read_sql('naf_miller_registration',engine_read_govt)
df33 = pd.read_sql('naf_miller_report',engine_read_govt)
df34 = pd.read_sql('naf_otr_commodity',engine_read_govt)
df35 = pd.read_sql('naf_otr_dec_docs',engine_read_govt)
df36 = pd.read_sql('naf_otr_dispatch',engine_read_govt)
df37 = pd.read_sql('naf_otr_distributed',engine_read_govt)
df38 = pd.read_sql('naf_otr_odr_map',engine_read_govt)
df39 = pd.read_sql('naf_otr_order',engine_read_govt)
df40 = pd.read_sql('naf_otr_order_files',engine_read_govt)
df41 = pd.read_sql('naf_otr_stocks',engine_read_govt)
df42 = pd.read_sql('naf_outturn_delivery_auc_details',engine_read_govt)
df43 = pd.read_sql('naf_outturn_stock_details',engine_read_govt)
df44 = pd.read_sql('naf_pds_challan',engine_read_govt)
df45 = pd.read_sql('naf_pds_return',engine_read_govt)
df46 = pd.read_sql('naf_pds_transit_history',engine_read_govt)
df47 = pd.read_sql('naf_price_delivery_auc_details',engine_read_govt)
df48 = pd.read_sql('naf_price_stock_details',engine_read_govt)
df49 = pd.read_sql('naf_pss_auctions',engine_read_govt)
df50 = pd.read_sql('naf_pss_bid_logger',engine_read_govt)
df51 = pd.read_sql('naf_pss_bids',engine_read_govt)
df52 = pd.read_sql('naf_pss_stocks',engine_read_govt)
df53 = pd.read_sql('naf_shipped_goods',engine_read_govt)
df54 = pd.read_sql('naf_sno_sla_dla_map',engine_read_govt)
df55 = pd.read_sql('naf_stocks',engine_read_govt)
df56 = pd.read_sql('naf_up_pds_master',engine_read_govt)
df57 = pd.read_sql('naf_user_log',engine_read_govt)
df58 = pd.read_sql('naf_user_sessions',engine_read_govt)
df59 = pd.read_sql('naf_variables',engine_read_govt)
df60 = pd.read_sql('naf_wishlist',engine_read_govt)
df61 = pd.read_sql('naf_yankee_auctions',engine_read_govt)
df62 = pd.read_sql('naf_yankee_bid_logger',engine_read_govt)
df63 = pd.read_sql('naf_yankee_bids',engine_read_govt)
df64 = pd.read_sql('naf_yankee_stocks',engine_read_govt)
df65 = pd.read_sql('pss_sms_text',engine_read_govt)
df66 = pd.read_sql('st_admins',engine_read_govt)
df67 = pd.read_sql('st_auc_time_slots',engine_read_govt)
df68 = pd.read_sql('st_bid_logger',engine_read_govt)
df69 = pd.read_sql('st_buy_auctions',engine_read_govt)
df70 = pd.read_sql('st_buyauc_com_params',engine_read_govt)
df71 = pd.read_sql('st_buyer_auction_bids',engine_read_govt)
df72 = pd.read_sql('st_com_params',engine_read_govt)
df73 = pd.read_sql('st_commodities',engine_read_govt)
df74 = pd.read_sql('st_pg_info',engine_read_govt)
df75 = pd.read_sql('st_pg_transactions',engine_read_govt)
df76 = pd.read_sql('st_pg_user_accounts',engine_read_govt)
df77 = pd.read_sql('st_sell_auctions',engine_read_govt)
df78 = pd.read_sql('st_sell_auctions_archives',engine_read_govt)
df79 = pd.read_sql('st_sellauc_com_params',engine_read_govt)
df80 = pd.read_sql('st_seller_auction_bids',engine_read_govt)
df81 = pd.read_sql('st_trade_chats',engine_read_govt)
df82 = pd.read_sql('st_trades',engine_read_govt)
df83 = pd.read_sql('st_user_bank_accounts',engine_read_govt)
df84 = pd.read_sql('st_user_payment_log',engine_read_govt)
df85 = pd.read_sql('temp_sms_sending',engine_read_govt)
df86 = pd.read_sql('up_icds',engine_read_govt)
df87 = pd.read_sql('yankee_sms_text',engine_read_govt)

# %%
# push data to nafed
df1.to_sql('abc_otp',engine_write,index=False,if_exists='replace', schema='nafed')
df2.to_sql('abc_users_groups',engine_write,index=False,if_exists='replace', schema='nafed')
df3.to_sql('abc_users_groups_map',engine_write,index=False,if_exists='replace', schema='nafed')
df4.to_sql('auction_multiple_docs',engine_write,index=False,if_exists='replace', schema='nafed')
df5.to_sql('client_logs',engine_write,index=False,if_exists='replace', schema='nafed')
df6.to_sql('countries',engine_write,index=False,if_exists='replace', schema='nafed')
df7.to_sql('icds_api_logs',engine_write,index=False,if_exists='replace', schema='nafed')
df8.to_sql('icds_center_master',engine_write,index=False,if_exists='replace', schema='nafed')
df9.to_sql('icds_delivery_report',engine_write,index=False,if_exists='replace', schema='nafed')
df10.to_sql('icds_primary_dispatch',engine_write,index=False,if_exists='replace', schema='nafed')
df11.to_sql('migrations',engine_write,index=False,if_exists='replace', schema='nafed')
df12.to_sql('milling_sms_text',engine_write,index=False,if_exists='replace', schema='nafed')
df13.to_sql('naf_areas',engine_write,index=False,if_exists='replace', schema='nafed')
df14.to_sql('naf_auc_stock_map',engine_write,index=False,if_exists='replace', schema='nafed')
df15.to_sql('naf_branch_users_map',engine_write,index=False,if_exists='replace', schema='nafed')
df16.to_sql('naf_branches',engine_write,index=False,if_exists='replace', schema='nafed')
df17.to_sql('naf_com_units',engine_write,index=False,if_exists='replace', schema='nafed')
df18.to_sql('naf_commodity_group',engine_write,index=False,if_exists='replace', schema='nafed')
df19.to_sql('naf_cron_locks',engine_write,index=False,if_exists='replace', schema='nafed')
df20.to_sql('naf_district_odr_map',engine_write,index=False,if_exists='replace', schema='nafed')
df21.to_sql('naf_do_raised',engine_write,index=False,if_exists='replace', schema='nafed')
df22.to_sql('naf_document_master',engine_write,index=False,if_exists='replace', schema='nafed')
df23.to_sql('naf_due_payments',engine_write,index=False,if_exists='replace', schema='nafed')
df24.to_sql('naf_itd_docs',engine_write,index=False,if_exists='replace', schema='nafed')
df25.to_sql('naf_itd_forms',engine_write,index=False,if_exists='replace', schema='nafed')
df26.to_sql('naf_miller',engine_write,index=False,if_exists='replace', schema='nafed')
df27.to_sql('naf_miller_copy',engine_write,index=False,if_exists='replace', schema='nafed')
df28.to_sql('naf_miller_docs_mapping',engine_write,index=False,if_exists='replace', schema='nafed')
df29.to_sql('naf_miller_plant_doc',engine_write,index=False,if_exists='replace', schema='nafed')
df30.to_sql('naf_miller_plant_info',engine_write,index=False,if_exists='replace', schema='nafed')
df31.to_sql('naf_miller_plants',engine_write,index=False,if_exists='replace', schema='nafed')
df32.to_sql('naf_miller_registration',engine_write,index=False,if_exists='replace', schema='nafed')
df33.to_sql('naf_miller_report',engine_write,index=False,if_exists='replace', schema='nafed')
df34.to_sql('naf_otr_commodity',engine_write,index=False,if_exists='replace', schema='nafed')
df35.to_sql('naf_otr_dec_docs',engine_write,index=False,if_exists='replace', schema='nafed')
df36.to_sql('naf_otr_dispatch',engine_write,index=False,if_exists='replace', schema='nafed')
df37.to_sql('naf_otr_distributed',engine_write,index=False,if_exists='replace', schema='nafed')
df38.to_sql('naf_otr_odr_map',engine_write,index=False,if_exists='replace', schema='nafed')
df39.to_sql('naf_otr_order',engine_write,index=False,if_exists='replace', schema='nafed')
df40.to_sql('naf_otr_order_files',engine_write,index=False,if_exists='replace', schema='nafed')
df41.to_sql('naf_otr_stocks',engine_write,index=False,if_exists='replace', schema='nafed')
df42.to_sql('naf_outturn_delivery_auc_details',engine_write,index=False,if_exists='replace', schema='nafed')
df43.to_sql('naf_outturn_stock_details',engine_write,index=False,if_exists='replace', schema='nafed')
df44.to_sql('naf_pds_challan',engine_write,index=False,if_exists='replace', schema='nafed')
df45.to_sql('naf_pds_return',engine_write,index=False,if_exists='replace', schema='nafed')
df46.to_sql('naf_pds_transit_history',engine_write,index=False,if_exists='replace', schema='nafed')
df47.to_sql('naf_price_delivery_auc_details',engine_write,index=False,if_exists='replace', schema='nafed')
df48.to_sql('naf_price_stock_details',engine_write,index=False,if_exists='replace', schema='nafed')
df49.to_sql('naf_pss_auctions',engine_write,index=False,if_exists='replace', schema='nafed')
df50.to_sql('naf_pss_bid_logger',engine_write,index=False,if_exists='replace', schema='nafed')
df51.to_sql('naf_pss_bids',engine_write,index=False,if_exists='replace', schema='nafed')
df52.to_sql('naf_pss_stocks',engine_write,index=False,if_exists='replace', schema='nafed')
df53.to_sql('naf_shipped_goods',engine_write,index=False,if_exists='replace', schema='nafed')
df54.to_sql('naf_sno_sla_dla_map',engine_write,index=False,if_exists='replace', schema='nafed')
df55.to_sql('naf_stocks',engine_write,index=False,if_exists='replace', schema='nafed')
df56.to_sql('naf_up_pds_master',engine_write,index=False,if_exists='replace', schema='nafed')
df57.to_sql('naf_user_log',engine_write,index=False,if_exists='replace', schema='nafed')
df58.to_sql('naf_user_sessions',engine_write,index=False,if_exists='replace', schema='nafed')
df59.to_sql('naf_variables',engine_write,index=False,if_exists='replace', schema='nafed')
df60.to_sql('naf_wishlist',engine_write,index=False,if_exists='replace', schema='nafed')
df61.to_sql('naf_yankee_auctions',engine_write,index=False,if_exists='replace', schema='nafed')
df62.to_sql('naf_yankee_bid_logger',engine_write,index=False,if_exists='replace', schema='nafed')
df63.to_sql('naf_yankee_bids',engine_write,index=False,if_exists='replace', schema='nafed')
df64.to_sql('naf_yankee_stocks',engine_write,index=False,if_exists='replace', schema='nafed')
df65.to_sql('pss_sms_text',engine_write,index=False,if_exists='replace', schema='nafed')
df66.to_sql('st_admins',engine_write,index=False,if_exists='replace', schema='nafed')
df67.to_sql('st_auc_time_slots',engine_write,index=False,if_exists='replace', schema='nafed')
df68.to_sql('st_bid_logger',engine_write,index=False,if_exists='replace', schema='nafed')
df69.to_sql('st_buy_auctions',engine_write,index=False,if_exists='replace', schema='nafed')
df70.to_sql('st_buyauc_com_params',engine_write,index=False,if_exists='replace', schema='nafed')
df71.to_sql('st_buyer_auction_bids',engine_write,index=False,if_exists='replace', schema='nafed')
df72.to_sql('st_com_params',engine_write,index=False,if_exists='replace', schema='nafed')
df73.to_sql('st_commodities',engine_write,index=False,if_exists='replace', schema='nafed')
df74.to_sql('st_pg_info',engine_write,index=False,if_exists='replace', schema='nafed')
df75.to_sql('st_pg_transactions',engine_write,index=False,if_exists='replace', schema='nafed')
df76.to_sql('st_pg_user_accounts',engine_write,index=False,if_exists='replace', schema='nafed')
df77.to_sql('st_sell_auctions',engine_write,index=False,if_exists='replace', schema='nafed')
df78.to_sql('st_sell_auctions_archives',engine_write,index=False,if_exists='replace', schema='nafed')
df79.to_sql('st_sellauc_com_params',engine_write,index=False,if_exists='replace', schema='nafed')
df80.to_sql('st_seller_auction_bids',engine_write,index=False,if_exists='replace', schema='nafed')
df81.to_sql('st_trade_chats',engine_write,index=False,if_exists='replace', schema='nafed')
df82.to_sql('st_trades',engine_write,index=False,if_exists='replace', schema='nafed')
df83.to_sql('st_user_bank_accounts',engine_write,index=False,if_exists='replace', schema='nafed')
df84.to_sql('st_user_payment_log',engine_write,index=False,if_exists='replace', schema='nafed')
df85.to_sql('temp_sms_sending',engine_write,index=False,if_exists='replace', schema='nafed')
df86.to_sql('up_icds',engine_write,index=False,if_exists='replace', schema='nafed')
df87.to_sql('yankee_sms_text',engine_write,index=False,if_exists='replace', schema='nafed')
