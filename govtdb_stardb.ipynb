# %%
import pandas as pd
import sqlalchemy
from datetime import datetime

# %%
engine_read_govt_stardb = sqlalchemy.create_engine('mysql+pymysql://manoj:cJtDsZ4UF6djRRXg@server12.agribazaar.com:3307/Stardb')
engine_read_govt = sqlalchemy.create_engine('mysql+pymysql://manoj:cJtDsZ4UF6djRRXg@server12.agribazaar.com:3307/nafed')
engine_read_govt_plogs = sqlalchemy.create_engine('mysql+pymysql://manoj:cJtDsZ4UF6djRRXg@server12.agribazaar.com:3307/plogs')

# %%
engine_write = sqlalchemy.create_engine('mysql+pymysql://manoj:cJtDsZ4UF6djRRXg@agri-reports.c2c32urb2pzx.ap-south-1.rds.amazonaws.com:3306/agri_reports')

# %%
# read from stardb
df1001=pd.read_sql('ClientAuctionsType',engine_read_govt_stardb)
df1002=pd.read_sql('abc_address_book',engine_read_govt_stardb)
df1003=pd.read_sql('abc_admin_defaultPermission',engine_read_govt_stardb)
df1004=pd.read_sql('abc_admin_permission',engine_read_govt_stardb)
df1005=pd.read_sql('abc_attribute_values',engine_read_govt_stardb)
df1006=pd.read_sql('abc_auc_cur_conversion',engine_read_govt_stardb)
df1007=pd.read_sql('abc_auc_deductions',engine_read_govt_stardb)
df1008=pd.read_sql('abc_bids_processing',engine_read_govt_stardb)
df1009=pd.read_sql('abc_bids_processing_13_10_20',engine_read_govt_stardb)
df1010=pd.read_sql('abc_bids_processing_old',engine_read_govt_stardb)
df1011=pd.read_sql('abc_bulkUpload_master',engine_read_govt_stardb)
df1012=pd.read_sql('abc_buy_list',engine_read_govt_stardb)
df1013=pd.read_sql('abc_carousel_images',engine_read_govt_stardb)
df1014=pd.read_sql('abc_com_deductions',engine_read_govt_stardb)
df1015=pd.read_sql('abc_com_param_values',engine_read_govt_stardb)
df1016=pd.read_sql('abc_com_params',engine_read_govt_stardb)
df1017=pd.read_sql('abc_com_quality_param',engine_read_govt_stardb)
df1018=pd.read_sql('abc_com_template_emd',engine_read_govt_stardb)
df1019=pd.read_sql('abc_com_template_quality_value',engine_read_govt_stardb)
df1020=pd.read_sql('abc_comm_trade_groups',engine_read_govt_stardb)
df1021=pd.read_sql('abc_commodities',engine_read_govt_stardb)
df1022=pd.read_sql('abc_commodity_group',engine_read_govt_stardb)
df1023=pd.read_sql('abc_communication',engine_read_govt_stardb)
df1024=pd.read_sql('abc_contract_note_attribute_master',engine_read_govt_stardb)
df1025=pd.read_sql('abc_contract_note_template_master',engine_read_govt_stardb)
df1026=pd.read_sql('abc_contract_note_template_order',engine_read_govt_stardb)
df1027=pd.read_sql('abc_contract_note_trade_order',engine_read_govt_stardb)
df1028=pd.read_sql('abc_currencies',engine_read_govt_stardb)
df1029=pd.read_sql('abc_due_payments',engine_read_govt_stardb)
df1030=pd.read_sql('abc_english_auc_bid_logger',engine_read_govt_stardb)
df1031=pd.read_sql('abc_english_buy_bids',engine_read_govt_stardb)
df1032=pd.read_sql('abc_english_sell_bids',engine_read_govt_stardb)
df1033=pd.read_sql('abc_field_activity_image',engine_read_govt_stardb)
df1034=pd.read_sql('abc_fpo_information',engine_read_govt_stardb)
df1035=pd.read_sql('abc_gis_crop_assessment',engine_read_govt_stardb)
df1036=pd.read_sql('abc_gis_request',engine_read_govt_stardb)
df1037=pd.read_sql('abc_insufficient_balance_logs',engine_read_govt_stardb)
df1038=pd.read_sql('abc_invoice_docs',engine_read_govt_stardb)
df1039=pd.read_sql('abc_invoice_reports',engine_read_govt_stardb)
df1040=pd.read_sql('abc_lab_master',engine_read_govt_stardb)
df1041=pd.read_sql('abc_lab_requests',engine_read_govt_stardb)
df1042=pd.read_sql('abc_lab_requests_param',engine_read_govt_stardb)
df1043=pd.read_sql('abc_lab_states',engine_read_govt_stardb)
df1044=pd.read_sql('abc_lift_param_value',engine_read_govt_stardb)
df1045=pd.read_sql('abc_lifting',engine_read_govt_stardb)
df1046=pd.read_sql('abc_mandi_price',engine_read_govt_stardb)
df1047=pd.read_sql('abc_mandi_sequence',engine_read_govt_stardb)
df1048=pd.read_sql('abc_master_permission',engine_read_govt_stardb)
df1049=pd.read_sql('abc_modules',engine_read_govt_stardb)
df1050=pd.read_sql('abc_nego_attr_values',engine_read_govt_stardb)
df1051=pd.read_sql('abc_nego_attributes',engine_read_govt_stardb)
df1052=pd.read_sql('abc_nego_docs',engine_read_govt_stardb)
df1053=pd.read_sql('abc_nego_mail_map',engine_read_govt_stardb)
df1054=pd.read_sql('abc_nego_trade_bid_log',engine_read_govt_stardb)
df1055=pd.read_sql('abc_nego_trade_bids',engine_read_govt_stardb)
df1056=pd.read_sql('abc_nego_trades',engine_read_govt_stardb)
df1057=pd.read_sql('abc_nomination_leads',engine_read_govt_stardb)
df1058=pd.read_sql('abc_nomination_log',engine_read_govt_stardb)
df1059=pd.read_sql('abc_nominations',engine_read_govt_stardb)
df1060=pd.read_sql('abc_nominations_payments',engine_read_govt_stardb)
df1061=pd.read_sql('abc_otp',engine_read_govt_stardb)
df1062=pd.read_sql('abc_payment_init_status',engine_read_govt_stardb)
df1063=pd.read_sql('abc_rating_master',engine_read_govt_stardb)
df1064=pd.read_sql('abc_rating_param',engine_read_govt_stardb)
df1065=pd.read_sql('abc_running_cron',engine_read_govt_stardb)
df1066=pd.read_sql('abc_search_helper',engine_read_govt_stardb)
df1067=pd.read_sql('abc_search_suggester',engine_read_govt_stardb)
df1068=pd.read_sql('abc_season',engine_read_govt_stardb)
df1069=pd.read_sql('abc_seed_notification',engine_read_govt_stardb)
df1070=pd.read_sql('abc_sell_list',engine_read_govt_stardb)
df1071=pd.read_sql('abc_settleDocs',engine_read_govt_stardb)
df1072=pd.read_sql('abc_settlement',engine_read_govt_stardb)
df1073=pd.read_sql('abc_states',engine_read_govt_stardb)
df1074=pd.read_sql('abc_stats',engine_read_govt_stardb)
df1075=pd.read_sql('abc_stock_history',engine_read_govt_stardb)
df1076=pd.read_sql('abc_stock_param_values',engine_read_govt_stardb)
df1077=pd.read_sql('abc_stock_ref',engine_read_govt_stardb)
df1078=pd.read_sql('abc_stock_ref_history',engine_read_govt_stardb)
df1079=pd.read_sql('abc_stock_truck',engine_read_govt_stardb)
df1080=pd.read_sql('abc_stocks',engine_read_govt_stardb)
df1081=pd.read_sql('abc_sub_permission',engine_read_govt_stardb)
df1082=pd.read_sql('abc_supplier_information',engine_read_govt_stardb)
df1083=pd.read_sql('abc_suppliers',engine_read_govt_stardb)
df1084=pd.read_sql('abc_template_attributes',engine_read_govt_stardb)
df1085=pd.read_sql('abc_template_attributes_master',engine_read_govt_stardb)
df1086=pd.read_sql('abc_templates',engine_read_govt_stardb)
df1087=pd.read_sql('abc_testimonial',engine_read_govt_stardb)
df1088=pd.read_sql('abc_token',engine_read_govt_stardb)
df1089=pd.read_sql('abc_trade_contract_note',engine_read_govt_stardb)
df1090=pd.read_sql('abc_user_logging',engine_read_govt_stardb)
df1091=pd.read_sql('abc_user_token',engine_read_govt_stardb)
df1092=pd.read_sql('abc_users_groups',engine_read_govt_stardb)
df1093=pd.read_sql('abc_users_groups_map',engine_read_govt_stardb)
df1094=pd.read_sql('abc_users_revenue',engine_read_govt_stardb)
df1095=pd.read_sql('abc_vehicle_type',engine_read_govt_stardb)
df1096=pd.read_sql('abc_wishlist',engine_read_govt_stardb)
df1097=pd.read_sql('abc_yankee_auc_bid_logger',engine_read_govt_stardb)
df1098=pd.read_sql('abc_yankee_auc_bid_logger_01_11_18',engine_read_govt_stardb)
df1099=pd.read_sql('abc_yankee_buy_bids',engine_read_govt_stardb)
df1100=pd.read_sql('abc_yankee_sell_bids',engine_read_govt_stardb)
df1101=pd.read_sql('abc_yankee_sell_bids_01_11_18',engine_read_govt_stardb)
df1102=pd.read_sql('auction_multiple_docs',engine_read_govt_stardb)
df1103=pd.read_sql('ck_crop_attribute',engine_read_govt_stardb)
df1104=pd.read_sql('ck_crop_attribute_detail',engine_read_govt_stardb)
df1105=pd.read_sql('ck_crop_disease',engine_read_govt_stardb)
df1106=pd.read_sql('ck_crop_disease_attr_detail',engine_read_govt_stardb)
df1107=pd.read_sql('ck_crop_disease_attribute',engine_read_govt_stardb)
df1108=pd.read_sql('ck_crop_disease_mapping',engine_read_govt_stardb)
df1109=pd.read_sql('ck_crop_stage',engine_read_govt_stardb)
df1110=pd.read_sql('ck_crop_stage_image',engine_read_govt_stardb)
df1111=pd.read_sql('ck_disease_medicine',engine_read_govt_stardb)
df1112=pd.read_sql('ck_disease_medicine_mapping',engine_read_govt_stardb)
df1113=pd.read_sql('ck_disease_type',engine_read_govt_stardb)
df1114=pd.read_sql('ck_farmer_activity_task',engine_read_govt_stardb)
df1115=pd.read_sql('ck_farmer_seed_reply',engine_read_govt_stardb)
df1116=pd.read_sql('ck_farmer_seed_reply_image',engine_read_govt_stardb)
df1117=pd.read_sql('ck_field_staff_activity',engine_read_govt_stardb)
df1118=pd.read_sql('ck_medicine',engine_read_govt_stardb)
df1119=pd.read_sql('ck_seed_company_task',engine_read_govt_stardb)
df1120=pd.read_sql('ck_seed_farmer_mapping',engine_read_govt_stardb)
df1121=pd.read_sql('ck_seed_program',engine_read_govt_stardb)
df1122=pd.read_sql('ck_seed_program_stage',engine_read_govt_stardb)
df1123=pd.read_sql('ck_seed_program_task_plan',engine_read_govt_stardb)
df1124=pd.read_sql('ck_task_image',engine_read_govt_stardb)
df1125=pd.read_sql('client_logs',engine_read_govt_stardb)
df1126=pd.read_sql('comm_template',engine_read_govt_stardb)
df1127=pd.read_sql('communication_config',engine_read_govt_stardb)
df1128=pd.read_sql('countries',engine_read_govt_stardb)
df1129=pd.read_sql('crf_addons',engine_read_govt_stardb)
df1130=pd.read_sql('crf_authorisation',engine_read_govt_stardb)
df1131=pd.read_sql('crf_banks',engine_read_govt_stardb)
df1132=pd.read_sql('crf_client_type',engine_read_govt_stardb)
df1133=pd.read_sql('crf_crops',engine_read_govt_stardb)
df1134=pd.read_sql('crf_docs',engine_read_govt_stardb)
df1135=pd.read_sql('crf_ekyc',engine_read_govt_stardb)
df1136=pd.read_sql('crf_factory',engine_read_govt_stardb)
df1137=pd.read_sql('crf_factory_plant',engine_read_govt_stardb)
df1138=pd.read_sql('crf_farmer',engine_read_govt_stardb)
df1139=pd.read_sql('crf_financials',engine_read_govt_stardb)
df1140=pd.read_sql('crf_firf_bank_parent',engine_read_govt_stardb)
df1141=pd.read_sql('crf_ifsc',engine_read_govt_stardb)
df1142=pd.read_sql('crf_locations',engine_read_govt_stardb)
df1143=pd.read_sql('crf_mandi_license',engine_read_govt_stardb)
df1144=pd.read_sql('crf_master',engine_read_govt_stardb)
df1145=pd.read_sql('crf_postalcodes',engine_read_govt_stardb)
df1146=pd.read_sql('ct_lab_testing',engine_read_govt_stardb)
df1147=pd.read_sql('defaulters',engine_read_govt_stardb)
df1148=pd.read_sql('do_leaves',engine_read_govt_stardb)
df1149=pd.read_sql('ems_category',engine_read_govt_stardb)
df1150=pd.read_sql('ems_ticket_thread',engine_read_govt_stardb)
df1151=pd.read_sql('ems_tickets',engine_read_govt_stardb)
df1152=pd.read_sql('ems_users',engine_read_govt_stardb)
df1153=pd.read_sql('farm_crop_history',engine_read_govt_stardb)
df1154=pd.read_sql('farm_npk',engine_read_govt_stardb)
df1155=pd.read_sql('fp_buyers',engine_read_govt_stardb)
df1156=pd.read_sql('fp_com_grades',engine_read_govt_stardb)
df1157=pd.read_sql('fp_demographic',engine_read_govt_stardb)
df1158=pd.read_sql('fp_employee_master',engine_read_govt_stardb)
df1159=pd.read_sql('fp_exit_ref',engine_read_govt_stardb)
df1160=pd.read_sql('fp_exits',engine_read_govt_stardb)
df1161=pd.read_sql('fp_lookups',engine_read_govt_stardb)
df1162=pd.read_sql('fp_msp_stock',engine_read_govt_stardb)
df1163=pd.read_sql('fp_msp_stock_exit',engine_read_govt_stardb)
df1164=pd.read_sql('fp_pc',engine_read_govt_stardb)
df1165=pd.read_sql('fp_pc_comm_setup',engine_read_govt_stardb)
df1166=pd.read_sql('fp_pc_infrastructure',engine_read_govt_stardb)
df1167=pd.read_sql('fp_pc_msp',engine_read_govt_stardb)
df1168=pd.read_sql('fp_request_employee',engine_read_govt_stardb)
df1169=pd.read_sql('fp_state_pc_target',engine_read_govt_stardb)
df1170=pd.read_sql('fp_state_target',engine_read_govt_stardb)
df1171=pd.read_sql('fp_warehouse',engine_read_govt_stardb)
df1172=pd.read_sql('ft_bank',engine_read_govt_stardb)
df1173=pd.read_sql('ft_commodities',engine_read_govt_stardb)
df1174=pd.read_sql('ft_depositor',engine_read_govt_stardb)
df1175=pd.read_sql('ft_depositor_gst_detail',engine_read_govt_stardb)
df1176=pd.read_sql('ft_mandi',engine_read_govt_stardb)
df1177=pd.read_sql('ft_pg_user_accounts',engine_read_govt_stardb)
df1178=pd.read_sql('ft_state',engine_read_govt_stardb)
df1179=pd.read_sql('ft_varieties',engine_read_govt_stardb)
df1180=pd.read_sql('geography_mapping_location',engine_read_govt_stardb)
df1181=pd.read_sql('gt_crop_master',engine_read_govt_stardb)
df1182=pd.read_sql('heatmap_weather',engine_read_govt_stardb)
df1183=pd.read_sql('imp_demand_projection',engine_read_govt_stardb)
df1184=pd.read_sql('imp_demand_projection_crop',engine_read_govt_stardb)
df1185=pd.read_sql('imp_files',engine_read_govt_stardb)
df1186=pd.read_sql('imp_fpo_bank_accounts',engine_read_govt_stardb)
df1187=pd.read_sql('imp_product_billing',engine_read_govt_stardb)
df1188=pd.read_sql('imp_supplier_bank_accounts',engine_read_govt_stardb)
df1189=pd.read_sql('imp_units',engine_read_govt_stardb)
df1190=pd.read_sql('lab_locations',engine_read_govt_stardb)
df1191=pd.read_sql('lab_service_state',engine_read_govt_stardb)
df1192=pd.read_sql('lifting_details',engine_read_govt_stardb)
df1193=pd.read_sql('lookup_master',engine_read_govt_stardb)
df1194=pd.read_sql('lookup_parents',engine_read_govt_stardb)
df1195=pd.read_sql('lookups',engine_read_govt_stardb)
df1196=pd.read_sql('migrations',engine_read_govt_stardb)
df1197=pd.read_sql('ml_log',engine_read_govt_stardb)
df1198=pd.read_sql('nabc_com_deductions',engine_read_govt_stardb)
df1199=pd.read_sql('nabc_com_param_map',engine_read_govt_stardb)
df1200=pd.read_sql('nabc_com_params',engine_read_govt_stardb)
df1201=pd.read_sql('nabc_unit_converter',engine_read_govt_stardb)
df1202=pd.read_sql('nabc_units',engine_read_govt_stardb)
df1203=pd.read_sql('nupay_api_logs',engine_read_govt_stardb)
df1204=pd.read_sql('nupay_api_logs_old',engine_read_govt_stardb)
df1205=pd.read_sql('offline_payments',engine_read_govt_stardb)
df1206=pd.read_sql('paymentFailedEmail',engine_read_govt_stardb)
df1207=pd.read_sql('pre_ae_common_logs',engine_read_govt_stardb)
df1208=pd.read_sql('pre_category',engine_read_govt_stardb)
df1209=pd.read_sql('pre_commodity_master',engine_read_govt_stardb)
df1210=pd.read_sql('pre_company',engine_read_govt_stardb)
df1211=pd.read_sql('pre_crop_details',engine_read_govt_stardb)
df1212=pd.read_sql('pre_crop_master',engine_read_govt_stardb)
df1213=pd.read_sql('pre_crop_report',engine_read_govt_stardb)
df1214=pd.read_sql('pre_crop_varieties',engine_read_govt_stardb)
df1215=pd.read_sql('pre_customer_master',engine_read_govt_stardb)
df1216=pd.read_sql('pre_district',engine_read_govt_stardb)
df1217=pd.read_sql('pre_district_tehsil',engine_read_govt_stardb)
df1218=pd.read_sql('pre_download_image_links',engine_read_govt_stardb)
df1219=pd.read_sql('pre_download_que',engine_read_govt_stardb)
df1220=pd.read_sql('pre_farm_to_crop_details',engine_read_govt_stardb)
df1221=pd.read_sql('pre_farmer_details',engine_read_govt_stardb)
df1222=pd.read_sql('pre_farmer_khasra_map',engine_read_govt_stardb)
df1223=pd.read_sql('pre_farmer_revenue',engine_read_govt_stardb)
df1224=pd.read_sql('pre_farmer_variable',engine_read_govt_stardb)
df1225=pd.read_sql('pre_geoserver_ops',engine_read_govt_stardb)
df1226=pd.read_sql('pre_grn_order',engine_read_govt_stardb)
df1227=pd.read_sql('pre_grn_products_delivered',engine_read_govt_stardb)
df1228=pd.read_sql('pre_grn_supplier_payment',engine_read_govt_stardb)
df1229=pd.read_sql('pre_gt_points',engine_read_govt_stardb)
df1230=pd.read_sql('pre_gt_points_2020',engine_read_govt_stardb)
df1231=pd.read_sql('pre_khasra_boundary',engine_read_govt_stardb)
df1232=pd.read_sql('pre_khasra_info',engine_read_govt_stardb)
df1233=pd.read_sql('pre_lat_lang_centre',engine_read_govt_stardb)
df1234=pd.read_sql('pre_master_com_season',engine_read_govt_stardb)
df1235=pd.read_sql('pre_order',engine_read_govt_stardb)
df1236=pd.read_sql('pre_order_products',engine_read_govt_stardb)
df1237=pd.read_sql('pre_path_file',engine_read_govt_stardb)
df1238=pd.read_sql('pre_payment_logs',engine_read_govt_stardb)
df1239=pd.read_sql('pre_po_order',engine_read_govt_stardb)
df1240=pd.read_sql('pre_po_order_products',engine_read_govt_stardb)
df1241=pd.read_sql('pre_product_wise_ae_inventory',engine_read_govt_stardb)
df1242=pd.read_sql('pre_products',engine_read_govt_stardb)
df1243=pd.read_sql('pre_rm_halka',engine_read_govt_stardb)
df1244=pd.read_sql('pre_rnm_halka_mapping',engine_read_govt_stardb)
df1245=pd.read_sql('pre_states',engine_read_govt_stardb)
df1246=pd.read_sql('pre_survey_form',engine_read_govt_stardb)
df1247=pd.read_sql('pre_taluk',engine_read_govt_stardb)
df1248=pd.read_sql('pre_village',engine_read_govt_stardb)
df1249=pd.read_sql('register',engine_read_govt_stardb)
df1250=pd.read_sql('se_branches',engine_read_govt_stardb)
df1251=pd.read_sql('se_designation',engine_read_govt_stardb)
df1252=pd.read_sql('se_emp_roles',engine_read_govt_stardb)
df1253=pd.read_sql('se_employees',engine_read_govt_stardb)
df1254=pd.read_sql('seed_company_role',engine_read_govt_stardb)
df1255=pd.read_sql('set_all_docs',engine_read_govt_stardb)
df1256=pd.read_sql('set_attribute_values',engine_read_govt_stardb)
df1257=pd.read_sql('set_attributes_master',engine_read_govt_stardb)
df1258=pd.read_sql('set_com_param_values',engine_read_govt_stardb)
df1259=pd.read_sql('set_do_docs',engine_read_govt_stardb)
df1260=pd.read_sql('set_do_docs_log',engine_read_govt_stardb)
df1261=pd.read_sql('set_gmv_data',engine_read_govt_stardb)
df1262=pd.read_sql('set_manage_stock',engine_read_govt_stardb)
df1263=pd.read_sql('set_quality_params_toggles',engine_read_govt_stardb)
df1264=pd.read_sql('set_settlement_logs',engine_read_govt_stardb)
df1265=pd.read_sql('set_stock_grievance',engine_read_govt_stardb)
df1266=pd.read_sql('set_taxes',engine_read_govt_stardb)
df1267=pd.read_sql('set_trade_deductions',engine_read_govt_stardb)
df1268=pd.read_sql('set_trade_info',engine_read_govt_stardb)
df1269=pd.read_sql('set_truck_param_map',engine_read_govt_stardb)
df1270=pd.read_sql('set_users_info',engine_read_govt_stardb)
df1271=pd.read_sql('set_weight_breakup',engine_read_govt_stardb)
df1272=pd.read_sql('st_admins',engine_read_govt_stardb)
df1273=pd.read_sql('st_alliances',engine_read_govt_stardb)
df1274=pd.read_sql('st_app_defaults',engine_read_govt_stardb)
df1275=pd.read_sql('st_areas',engine_read_govt_stardb)
df1276=pd.read_sql('st_auc_time_slots',engine_read_govt_stardb)
df1277=pd.read_sql('st_bags',engine_read_govt_stardb)
df1278=pd.read_sql('st_bid_logger',engine_read_govt_stardb)
df1279=pd.read_sql('st_bsr',engine_read_govt_stardb)
df1280=pd.read_sql('st_bsr_archive',engine_read_govt_stardb)
df1281=pd.read_sql('st_bsr_mapping',engine_read_govt_stardb)
df1282=pd.read_sql('st_buy_auctions',engine_read_govt_stardb)
df1283=pd.read_sql('st_buy_orders',engine_read_govt_stardb)
df1284=pd.read_sql('st_buyauc_com_params',engine_read_govt_stardb)
df1285=pd.read_sql('st_buyeq_com_params',engine_read_govt_stardb)
df1286=pd.read_sql('st_buyer_auction_bids',engine_read_govt_stardb)
df1287=pd.read_sql('st_cis_cdf_entry',engine_read_govt_stardb)
df1288=pd.read_sql('st_client_docs_mapping',engine_read_govt_stardb)
df1289=pd.read_sql('st_client_registration',engine_read_govt_stardb)
df1290=pd.read_sql('st_cms',engine_read_govt_stardb)
df1291=pd.read_sql('st_com_deductions',engine_read_govt_stardb)
df1292=pd.read_sql('st_com_mandi_price',engine_read_govt_stardb)
df1293=pd.read_sql('st_com_params',engine_read_govt_stardb)
df1294=pd.read_sql('st_commodities',engine_read_govt_stardb)
df1295=pd.read_sql('st_company_users',engine_read_govt_stardb)
df1296=pd.read_sql('st_content',engine_read_govt_stardb)
df1297=pd.read_sql('st_directors',engine_read_govt_stardb)
df1298=pd.read_sql('st_document_master',engine_read_govt_stardb)
df1299=pd.read_sql('st_employees',engine_read_govt_stardb)
df1300=pd.read_sql('st_farmer_docs_mapping',engine_read_govt_stardb)
df1301=pd.read_sql('st_farmer_registration',engine_read_govt_stardb)
df1302=pd.read_sql('st_farmer_stock',engine_read_govt_stardb)
df1303=pd.read_sql('st_firm_details',engine_read_govt_stardb)
df1304=pd.read_sql('st_gst',engine_read_govt_stardb)
df1305=pd.read_sql('st_inventory',engine_read_govt_stardb)
df1306=pd.read_sql('st_labs',engine_read_govt_stardb)
df1307=pd.read_sql('st_locations',engine_read_govt_stardb)
df1308=pd.read_sql('st_mandis',engine_read_govt_stardb)
df1309=pd.read_sql('st_notifications_users',engine_read_govt_stardb)
df1310=pd.read_sql('st_offer_to_buy',engine_read_govt_stardb)
df1311=pd.read_sql('st_offer_to_sell',engine_read_govt_stardb)
df1312=pd.read_sql('st_offline_inventory',engine_read_govt_stardb)
df1313=pd.read_sql('st_offline_inventory_archive',engine_read_govt_stardb)
df1314=pd.read_sql('st_order_offers',engine_read_govt_stardb)
df1315=pd.read_sql('st_order_types',engine_read_govt_stardb)
df1316=pd.read_sql('st_pg_info',engine_read_govt_stardb)
df1317=pd.read_sql('st_pg_transactions',engine_read_govt_stardb)
df1318=pd.read_sql('st_pg_user_accounts',engine_read_govt_stardb)
df1319=pd.read_sql('st_pg_user_accounts_old',engine_read_govt_stardb)
df1320=pd.read_sql('st_pg_wallet',engine_read_govt_stardb)
df1321=pd.read_sql('st_search_tag',engine_read_govt_stardb)
df1322=pd.read_sql('st_sell_auctions',engine_read_govt_stardb)
df1323=pd.read_sql('st_sell_orders',engine_read_govt_stardb)
df1324=pd.read_sql('st_sellauc_com_params',engine_read_govt_stardb)
df1325=pd.read_sql('st_selleq_com_params',engine_read_govt_stardb)
df1326=pd.read_sql('st_seller_auction_bids',engine_read_govt_stardb)
df1327=pd.read_sql('st_sms_text',engine_read_govt_stardb)
df1328=pd.read_sql('st_states',engine_read_govt_stardb)
df1329=pd.read_sql('st_stock_com_params',engine_read_govt_stardb)
df1330=pd.read_sql('st_trade_chats',engine_read_govt_stardb)
df1331=pd.read_sql('st_trade_docs_map',engine_read_govt_stardb)
df1332=pd.read_sql('st_trade_docs_master',engine_read_govt_stardb)
df1333=pd.read_sql('st_trade_shipments',engine_read_govt_stardb)
df1334=pd.read_sql('st_trade_stages',engine_read_govt_stardb)
df1335=pd.read_sql('st_trade_taxes',engine_read_govt_stardb)
df1336=pd.read_sql('st_trade_trucks',engine_read_govt_stardb)
df1337=pd.read_sql('st_trades',engine_read_govt_stardb)
df1338=pd.read_sql('st_trades_transactions',engine_read_govt_stardb)
df1339=pd.read_sql('st_transports',engine_read_govt_stardb)
df1340=pd.read_sql('st_user_bank_accounts',engine_read_govt_stardb)
df1341=pd.read_sql('st_user_bank_accounts_old',engine_read_govt_stardb)
df1342=pd.read_sql('st_user_payment_log',engine_read_govt_stardb)
df1343=pd.read_sql('st_users',engine_read_govt_stardb)
df1344=pd.read_sql('st_users_old',engine_read_govt_stardb)
df1345=pd.read_sql('st_warehouses',engine_read_govt_stardb)
df1346=pd.read_sql('st_wr_sr_platform',engine_read_govt_stardb)
df1347=pd.read_sql('unsubscribe_email',engine_read_govt_stardb)
df1348=pd.read_sql('view_user_data_pvt',engine_read_govt_stardb)

# %%
# write to stardb
df1001.to_sql('ClientAuctionsType',engine_write,index=False,if_exists='replace', schema='stardb')
df1002.to_sql('abc_address_book',engine_write,index=False,if_exists='replace', schema='stardb')
df1003.to_sql('abc_admin_defaultPermission',engine_write,index=False,if_exists='replace', schema='stardb')
df1004.to_sql('abc_admin_permission',engine_write,index=False,if_exists='replace', schema='stardb')
df1005.to_sql('abc_attribute_values',engine_write,index=False,if_exists='replace', schema='stardb')
df1006.to_sql('abc_auc_cur_conversion',engine_write,index=False,if_exists='replace', schema='stardb')
df1007.to_sql('abc_auc_deductions',engine_write,index=False,if_exists='replace', schema='stardb')
df1008.to_sql('abc_bids_processing',engine_write,index=False,if_exists='replace', schema='stardb')
df1009.to_sql('abc_bids_processing_13_10_20',engine_write,index=False,if_exists='replace', schema='stardb')
df1010.to_sql('abc_bids_processing_old',engine_write,index=False,if_exists='replace', schema='stardb')
df1011.to_sql('abc_bulkUpload_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1012.to_sql('abc_buy_list',engine_write,index=False,if_exists='replace', schema='stardb')
df1013.to_sql('abc_carousel_images',engine_write,index=False,if_exists='replace', schema='stardb')
df1014.to_sql('abc_com_deductions',engine_write,index=False,if_exists='replace', schema='stardb')
df1015.to_sql('abc_com_param_values',engine_write,index=False,if_exists='replace', schema='stardb')
df1016.to_sql('abc_com_params',engine_write,index=False,if_exists='replace', schema='stardb')
df1017.to_sql('abc_com_quality_param',engine_write,index=False,if_exists='replace', schema='stardb')
df1018.to_sql('abc_com_template_emd',engine_write,index=False,if_exists='replace', schema='stardb')
df1019.to_sql('abc_com_template_quality_value',engine_write,index=False,if_exists='replace', schema='stardb')
df1020.to_sql('abc_comm_trade_groups',engine_write,index=False,if_exists='replace', schema='stardb')
df1021.to_sql('abc_commodities',engine_write,index=False,if_exists='replace', schema='stardb')
df1022.to_sql('abc_commodity_group',engine_write,index=False,if_exists='replace', schema='stardb')
df1023.to_sql('abc_communication',engine_write,index=False,if_exists='replace', schema='stardb')
df1024.to_sql('abc_contract_note_attribute_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1025.to_sql('abc_contract_note_template_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1026.to_sql('abc_contract_note_template_order',engine_write,index=False,if_exists='replace', schema='stardb')
df1027.to_sql('abc_contract_note_trade_order',engine_write,index=False,if_exists='replace', schema='stardb')
df1028.to_sql('abc_currencies',engine_write,index=False,if_exists='replace', schema='stardb')
df1029.to_sql('abc_due_payments',engine_write,index=False,if_exists='replace', schema='stardb')
df1030.to_sql('abc_english_auc_bid_logger',engine_write,index=False,if_exists='replace', schema='stardb')
df1031.to_sql('abc_english_buy_bids',engine_write,index=False,if_exists='replace', schema='stardb')
df1032.to_sql('abc_english_sell_bids',engine_write,index=False,if_exists='replace', schema='stardb')
df1033.to_sql('abc_field_activity_image',engine_write,index=False,if_exists='replace', schema='stardb')
df1034.to_sql('abc_fpo_information',engine_write,index=False,if_exists='replace', schema='stardb')
df1035.to_sql('abc_gis_crop_assessment',engine_write,index=False,if_exists='replace', schema='stardb')
df1036.to_sql('abc_gis_request',engine_write,index=False,if_exists='replace', schema='stardb')
df1037.to_sql('abc_insufficient_balance_logs',engine_write,index=False,if_exists='replace', schema='stardb')
df1038.to_sql('abc_invoice_docs',engine_write,index=False,if_exists='replace', schema='stardb')
df1039.to_sql('abc_invoice_reports',engine_write,index=False,if_exists='replace', schema='stardb')
df1040.to_sql('abc_lab_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1041.to_sql('abc_lab_requests',engine_write,index=False,if_exists='replace', schema='stardb')
df1042.to_sql('abc_lab_requests_param',engine_write,index=False,if_exists='replace', schema='stardb')
df1043.to_sql('abc_lab_states',engine_write,index=False,if_exists='replace', schema='stardb')
df1044.to_sql('abc_lift_param_value',engine_write,index=False,if_exists='replace', schema='stardb')
df1045.to_sql('abc_lifting',engine_write,index=False,if_exists='replace', schema='stardb')
df1046.to_sql('abc_mandi_price',engine_write,index=False,if_exists='replace', schema='stardb')
df1047.to_sql('abc_mandi_sequence',engine_write,index=False,if_exists='replace', schema='stardb')
df1048.to_sql('abc_master_permission',engine_write,index=False,if_exists='replace', schema='stardb')
df1049.to_sql('abc_modules',engine_write,index=False,if_exists='replace', schema='stardb')
df1050.to_sql('abc_nego_attr_values',engine_write,index=False,if_exists='replace', schema='stardb')
df1051.to_sql('abc_nego_attributes',engine_write,index=False,if_exists='replace', schema='stardb')
df1052.to_sql('abc_nego_docs',engine_write,index=False,if_exists='replace', schema='stardb')
df1053.to_sql('abc_nego_mail_map',engine_write,index=False,if_exists='replace', schema='stardb')
df1054.to_sql('abc_nego_trade_bid_log',engine_write,index=False,if_exists='replace', schema='stardb')
df1055.to_sql('abc_nego_trade_bids',engine_write,index=False,if_exists='replace', schema='stardb')
df1056.to_sql('abc_nego_trades',engine_write,index=False,if_exists='replace', schema='stardb')
df1057.to_sql('abc_nomination_leads',engine_write,index=False,if_exists='replace', schema='stardb')
df1058.to_sql('abc_nomination_log',engine_write,index=False,if_exists='replace', schema='stardb')
df1059.to_sql('abc_nominations',engine_write,index=False,if_exists='replace', schema='stardb')
df1060.to_sql('abc_nominations_payments',engine_write,index=False,if_exists='replace', schema='stardb')
df1061.to_sql('abc_otp',engine_write,index=False,if_exists='replace', schema='stardb')
df1062.to_sql('abc_payment_init_status',engine_write,index=False,if_exists='replace', schema='stardb')
df1063.to_sql('abc_rating_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1064.to_sql('abc_rating_param',engine_write,index=False,if_exists='replace', schema='stardb')
df1065.to_sql('abc_running_cron',engine_write,index=False,if_exists='replace', schema='stardb')
df1066.to_sql('abc_search_helper',engine_write,index=False,if_exists='replace', schema='stardb')
df1067.to_sql('abc_search_suggester',engine_write,index=False,if_exists='replace', schema='stardb')
df1068.to_sql('abc_season',engine_write,index=False,if_exists='replace', schema='stardb')
df1069.to_sql('abc_seed_notification',engine_write,index=False,if_exists='replace', schema='stardb')
df1070.to_sql('abc_sell_list',engine_write,index=False,if_exists='replace', schema='stardb')
df1071.to_sql('abc_settleDocs',engine_write,index=False,if_exists='replace', schema='stardb')
df1072.to_sql('abc_settlement',engine_write,index=False,if_exists='replace', schema='stardb')
df1073.to_sql('abc_states',engine_write,index=False,if_exists='replace', schema='stardb')
df1074.to_sql('abc_stats',engine_write,index=False,if_exists='replace', schema='stardb')
df1075.to_sql('abc_stock_history',engine_write,index=False,if_exists='replace', schema='stardb')
df1076.to_sql('abc_stock_param_values',engine_write,index=False,if_exists='replace', schema='stardb')
df1077.to_sql('abc_stock_ref',engine_write,index=False,if_exists='replace', schema='stardb')
df1078.to_sql('abc_stock_ref_history',engine_write,index=False,if_exists='replace', schema='stardb')
df1079.to_sql('abc_stock_truck',engine_write,index=False,if_exists='replace', schema='stardb')
df1080.to_sql('abc_stocks',engine_write,index=False,if_exists='replace', schema='stardb')
df1081.to_sql('abc_sub_permission',engine_write,index=False,if_exists='replace', schema='stardb')
df1082.to_sql('abc_supplier_information',engine_write,index=False,if_exists='replace', schema='stardb')
df1083.to_sql('abc_suppliers',engine_write,index=False,if_exists='replace', schema='stardb')
df1084.to_sql('abc_template_attributes',engine_write,index=False,if_exists='replace', schema='stardb')
df1085.to_sql('abc_template_attributes_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1086.to_sql('abc_templates',engine_write,index=False,if_exists='replace', schema='stardb')
df1087.to_sql('abc_testimonial',engine_write,index=False,if_exists='replace', schema='stardb')
df1088.to_sql('abc_token',engine_write,index=False,if_exists='replace', schema='stardb')
df1089.to_sql('abc_trade_contract_note',engine_write,index=False,if_exists='replace', schema='stardb')
df1090.to_sql('abc_user_logging',engine_write,index=False,if_exists='replace', schema='stardb')
df1091.to_sql('abc_user_token',engine_write,index=False,if_exists='replace', schema='stardb')
df1092.to_sql('abc_users_groups',engine_write,index=False,if_exists='replace', schema='stardb')
df1093.to_sql('abc_users_groups_map',engine_write,index=False,if_exists='replace', schema='stardb')
df1094.to_sql('abc_users_revenue',engine_write,index=False,if_exists='replace', schema='stardb')
df1095.to_sql('abc_vehicle_type',engine_write,index=False,if_exists='replace', schema='stardb')
df1096.to_sql('abc_wishlist',engine_write,index=False,if_exists='replace', schema='stardb')
df1097.to_sql('abc_yankee_auc_bid_logger',engine_write,index=False,if_exists='replace', schema='stardb')
df1098.to_sql('abc_yankee_auc_bid_logger_01_11_18',engine_write,index=False,if_exists='replace', schema='stardb')
df1099.to_sql('abc_yankee_buy_bids',engine_write,index=False,if_exists='replace', schema='stardb')
df1100.to_sql('abc_yankee_sell_bids',engine_write,index=False,if_exists='replace', schema='stardb')
df1101.to_sql('abc_yankee_sell_bids_01_11_18',engine_write,index=False,if_exists='replace', schema='stardb')
df1102.to_sql('auction_multiple_docs',engine_write,index=False,if_exists='replace', schema='stardb')
df1103.to_sql('ck_crop_attribute',engine_write,index=False,if_exists='replace', schema='stardb')
df1104.to_sql('ck_crop_attribute_detail',engine_write,index=False,if_exists='replace', schema='stardb')
df1105.to_sql('ck_crop_disease',engine_write,index=False,if_exists='replace', schema='stardb')
df1106.to_sql('ck_crop_disease_attr_detail',engine_write,index=False,if_exists='replace', schema='stardb')
df1107.to_sql('ck_crop_disease_attribute',engine_write,index=False,if_exists='replace', schema='stardb')
df1108.to_sql('ck_crop_disease_mapping',engine_write,index=False,if_exists='replace', schema='stardb')
df1109.to_sql('ck_crop_stage',engine_write,index=False,if_exists='replace', schema='stardb')
df1110.to_sql('ck_crop_stage_image',engine_write,index=False,if_exists='replace', schema='stardb')
df1111.to_sql('ck_disease_medicine',engine_write,index=False,if_exists='replace', schema='stardb')
df1112.to_sql('ck_disease_medicine_mapping',engine_write,index=False,if_exists='replace', schema='stardb')
df1113.to_sql('ck_disease_type',engine_write,index=False,if_exists='replace', schema='stardb')
df1114.to_sql('ck_farmer_activity_task',engine_write,index=False,if_exists='replace', schema='stardb')
df1115.to_sql('ck_farmer_seed_reply',engine_write,index=False,if_exists='replace', schema='stardb')
df1116.to_sql('ck_farmer_seed_reply_image',engine_write,index=False,if_exists='replace', schema='stardb')
df1117.to_sql('ck_field_staff_activity',engine_write,index=False,if_exists='replace', schema='stardb')
df1118.to_sql('ck_medicine',engine_write,index=False,if_exists='replace', schema='stardb')
df1119.to_sql('ck_seed_company_task',engine_write,index=False,if_exists='replace', schema='stardb')
df1120.to_sql('ck_seed_farmer_mapping',engine_write,index=False,if_exists='replace', schema='stardb')
df1121.to_sql('ck_seed_program',engine_write,index=False,if_exists='replace', schema='stardb')
df1122.to_sql('ck_seed_program_stage',engine_write,index=False,if_exists='replace', schema='stardb')
df1123.to_sql('ck_seed_program_task_plan',engine_write,index=False,if_exists='replace', schema='stardb')
df1124.to_sql('ck_task_image',engine_write,index=False,if_exists='replace', schema='stardb')
df1125.to_sql('client_logs',engine_write,index=False,if_exists='replace', schema='stardb')
df1126.to_sql('comm_template',engine_write,index=False,if_exists='replace', schema='stardb')
df1127.to_sql('communication_config',engine_write,index=False,if_exists='replace', schema='stardb')
df1128.to_sql('countries',engine_write,index=False,if_exists='replace', schema='stardb')
df1129.to_sql('crf_addons',engine_write,index=False,if_exists='replace', schema='stardb')
df1130.to_sql('crf_authorisation',engine_write,index=False,if_exists='replace', schema='stardb')
df1131.to_sql('crf_banks',engine_write,index=False,if_exists='replace', schema='stardb')
df1132.to_sql('crf_client_type',engine_write,index=False,if_exists='replace', schema='stardb')
df1133.to_sql('crf_crops',engine_write,index=False,if_exists='replace', schema='stardb')
df1134.to_sql('crf_docs',engine_write,index=False,if_exists='replace', schema='stardb')
df1135.to_sql('crf_ekyc',engine_write,index=False,if_exists='replace', schema='stardb')
df1136.to_sql('crf_factory',engine_write,index=False,if_exists='replace', schema='stardb')
df1137.to_sql('crf_factory_plant',engine_write,index=False,if_exists='replace', schema='stardb')
df1138.to_sql('crf_farmer',engine_write,index=False,if_exists='replace', schema='stardb')
df1139.to_sql('crf_financials',engine_write,index=False,if_exists='replace', schema='stardb')
df1140.to_sql('crf_firf_bank_parent',engine_write,index=False,if_exists='replace', schema='stardb')
df1141.to_sql('crf_ifsc',engine_write,index=False,if_exists='replace', schema='stardb')
df1142.to_sql('crf_locations',engine_write,index=False,if_exists='replace', schema='stardb')
df1143.to_sql('crf_mandi_license',engine_write,index=False,if_exists='replace', schema='stardb')
df1144.to_sql('crf_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1145.to_sql('crf_postalcodes',engine_write,index=False,if_exists='replace', schema='stardb')
df1146.to_sql('ct_lab_testing',engine_write,index=False,if_exists='replace', schema='stardb')
df1147.to_sql('defaulters',engine_write,index=False,if_exists='replace', schema='stardb')
df1148.to_sql('do_leaves',engine_write,index=False,if_exists='replace', schema='stardb')
df1149.to_sql('ems_category',engine_write,index=False,if_exists='replace', schema='stardb')
df1150.to_sql('ems_ticket_thread',engine_write,index=False,if_exists='replace', schema='stardb')
df1151.to_sql('ems_tickets',engine_write,index=False,if_exists='replace', schema='stardb')
df1152.to_sql('ems_users',engine_write,index=False,if_exists='replace', schema='stardb')
df1153.to_sql('farm_crop_history',engine_write,index=False,if_exists='replace', schema='stardb')
df1154.to_sql('farm_npk',engine_write,index=False,if_exists='replace', schema='stardb')
df1155.to_sql('fp_buyers',engine_write,index=False,if_exists='replace', schema='stardb')
df1156.to_sql('fp_com_grades',engine_write,index=False,if_exists='replace', schema='stardb')
df1157.to_sql('fp_demographic',engine_write,index=False,if_exists='replace', schema='stardb')
df1158.to_sql('fp_employee_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1159.to_sql('fp_exit_ref',engine_write,index=False,if_exists='replace', schema='stardb')
df1160.to_sql('fp_exits',engine_write,index=False,if_exists='replace', schema='stardb')
df1161.to_sql('fp_lookups',engine_write,index=False,if_exists='replace', schema='stardb')
df1162.to_sql('fp_msp_stock',engine_write,index=False,if_exists='replace', schema='stardb')
df1163.to_sql('fp_msp_stock_exit',engine_write,index=False,if_exists='replace', schema='stardb')
df1164.to_sql('fp_pc',engine_write,index=False,if_exists='replace', schema='stardb')
df1165.to_sql('fp_pc_comm_setup',engine_write,index=False,if_exists='replace', schema='stardb')
df1166.to_sql('fp_pc_infrastructure',engine_write,index=False,if_exists='replace', schema='stardb')
df1167.to_sql('fp_pc_msp',engine_write,index=False,if_exists='replace', schema='stardb')
df1168.to_sql('fp_request_employee',engine_write,index=False,if_exists='replace', schema='stardb')
df1169.to_sql('fp_state_pc_target',engine_write,index=False,if_exists='replace', schema='stardb')
df1170.to_sql('fp_state_target',engine_write,index=False,if_exists='replace', schema='stardb')
df1171.to_sql('fp_warehouse',engine_write,index=False,if_exists='replace', schema='stardb')
df1172.to_sql('ft_bank',engine_write,index=False,if_exists='replace', schema='stardb')
df1173.to_sql('ft_commodities',engine_write,index=False,if_exists='replace', schema='stardb')
df1174.to_sql('ft_depositor',engine_write,index=False,if_exists='replace', schema='stardb')
df1175.to_sql('ft_depositor_gst_detail',engine_write,index=False,if_exists='replace', schema='stardb')
df1176.to_sql('ft_mandi',engine_write,index=False,if_exists='replace', schema='stardb')
df1177.to_sql('ft_pg_user_accounts',engine_write,index=False,if_exists='replace', schema='stardb')
df1178.to_sql('ft_state',engine_write,index=False,if_exists='replace', schema='stardb')
df1179.to_sql('ft_varieties',engine_write,index=False,if_exists='replace', schema='stardb')
df1180.to_sql('geography_mapping_location',engine_write,index=False,if_exists='replace', schema='stardb')
df1181.to_sql('gt_crop_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1182.to_sql('heatmap_weather',engine_write,index=False,if_exists='replace', schema='stardb')
df1183.to_sql('imp_demand_projection',engine_write,index=False,if_exists='replace', schema='stardb')
df1184.to_sql('imp_demand_projection_crop',engine_write,index=False,if_exists='replace', schema='stardb')
df1185.to_sql('imp_files',engine_write,index=False,if_exists='replace', schema='stardb')
df1186.to_sql('imp_fpo_bank_accounts',engine_write,index=False,if_exists='replace', schema='stardb')
df1187.to_sql('imp_product_billing',engine_write,index=False,if_exists='replace', schema='stardb')
df1188.to_sql('imp_supplier_bank_accounts',engine_write,index=False,if_exists='replace', schema='stardb')
df1189.to_sql('imp_units',engine_write,index=False,if_exists='replace', schema='stardb')
df1190.to_sql('lab_locations',engine_write,index=False,if_exists='replace', schema='stardb')
df1191.to_sql('lab_service_state',engine_write,index=False,if_exists='replace', schema='stardb')
df1192.to_sql('lifting_details',engine_write,index=False,if_exists='replace', schema='stardb')
df1193.to_sql('lookup_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1194.to_sql('lookup_parents',engine_write,index=False,if_exists='replace', schema='stardb')
df1195.to_sql('lookups',engine_write,index=False,if_exists='replace', schema='stardb')
df1196.to_sql('migrations',engine_write,index=False,if_exists='replace', schema='stardb')
df1197.to_sql('ml_log',engine_write,index=False,if_exists='replace', schema='stardb')
df1198.to_sql('nabc_com_deductions',engine_write,index=False,if_exists='replace', schema='stardb')
df1199.to_sql('nabc_com_param_map',engine_write,index=False,if_exists='replace', schema='stardb')
df1200.to_sql('nabc_com_params',engine_write,index=False,if_exists='replace', schema='stardb')
df1201.to_sql('nabc_unit_converter',engine_write,index=False,if_exists='replace', schema='stardb')
df1202.to_sql('nabc_units',engine_write,index=False,if_exists='replace', schema='stardb')
df1203.to_sql('nupay_api_logs',engine_write,index=False,if_exists='replace', schema='stardb')
df1204.to_sql('nupay_api_logs_old',engine_write,index=False,if_exists='replace', schema='stardb')
df1205.to_sql('offline_payments',engine_write,index=False,if_exists='replace', schema='stardb')
df1206.to_sql('paymentFailedEmail',engine_write,index=False,if_exists='replace', schema='stardb')
df1207.to_sql('pre_ae_common_logs',engine_write,index=False,if_exists='replace', schema='stardb')
df1208.to_sql('pre_category',engine_write,index=False,if_exists='replace', schema='stardb')
df1209.to_sql('pre_commodity_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1210.to_sql('pre_company',engine_write,index=False,if_exists='replace', schema='stardb')
df1211.to_sql('pre_crop_details',engine_write,index=False,if_exists='replace', schema='stardb')
df1212.to_sql('pre_crop_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1213.to_sql('pre_crop_report',engine_write,index=False,if_exists='replace', schema='stardb')
df1214.to_sql('pre_crop_varieties',engine_write,index=False,if_exists='replace', schema='stardb')
df1215.to_sql('pre_customer_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1216.to_sql('pre_district',engine_write,index=False,if_exists='replace', schema='stardb')
df1217.to_sql('pre_district_tehsil',engine_write,index=False,if_exists='replace', schema='stardb')
df1218.to_sql('pre_download_image_links',engine_write,index=False,if_exists='replace', schema='stardb')
df1219.to_sql('pre_download_que',engine_write,index=False,if_exists='replace', schema='stardb')
df1220.to_sql('pre_farm_to_crop_details',engine_write,index=False,if_exists='replace', schema='stardb')
df1221.to_sql('pre_farmer_details',engine_write,index=False,if_exists='replace', schema='stardb')
df1222.to_sql('pre_farmer_khasra_map',engine_write,index=False,if_exists='replace', schema='stardb')
df1223.to_sql('pre_farmer_revenue',engine_write,index=False,if_exists='replace', schema='stardb')
df1224.to_sql('pre_farmer_variable',engine_write,index=False,if_exists='replace', schema='stardb')
df1225.to_sql('pre_geoserver_ops',engine_write,index=False,if_exists='replace', schema='stardb')
df1226.to_sql('pre_grn_order',engine_write,index=False,if_exists='replace', schema='stardb')
df1227.to_sql('pre_grn_products_delivered',engine_write,index=False,if_exists='replace', schema='stardb')
df1228.to_sql('pre_grn_supplier_payment',engine_write,index=False,if_exists='replace', schema='stardb')
df1229.to_sql('pre_gt_points',engine_write,index=False,if_exists='replace', schema='stardb')
df1230.to_sql('pre_gt_points_2020',engine_write,index=False,if_exists='replace', schema='stardb')
df1231.to_sql('pre_khasra_boundary',engine_write,index=False,if_exists='replace', schema='stardb')
df1232.to_sql('pre_khasra_info',engine_write,index=False,if_exists='replace', schema='stardb')
df1233.to_sql('pre_lat_lang_centre',engine_write,index=False,if_exists='replace', schema='stardb')
df1234.to_sql('pre_master_com_season',engine_write,index=False,if_exists='replace', schema='stardb')
df1235.to_sql('pre_order',engine_write,index=False,if_exists='replace', schema='stardb')
df1236.to_sql('pre_order_products',engine_write,index=False,if_exists='replace', schema='stardb')
df1237.to_sql('pre_path_file',engine_write,index=False,if_exists='replace', schema='stardb')
df1238.to_sql('pre_payment_logs',engine_write,index=False,if_exists='replace', schema='stardb')
df1239.to_sql('pre_po_order',engine_write,index=False,if_exists='replace', schema='stardb')
df1240.to_sql('pre_po_order_products',engine_write,index=False,if_exists='replace', schema='stardb')
df1241.to_sql('pre_product_wise_ae_inventory',engine_write,index=False,if_exists='replace', schema='stardb')
df1242.to_sql('pre_products',engine_write,index=False,if_exists='replace', schema='stardb')
df1243.to_sql('pre_rm_halka',engine_write,index=False,if_exists='replace', schema='stardb')
df1244.to_sql('pre_rnm_halka_mapping',engine_write,index=False,if_exists='replace', schema='stardb')
df1245.to_sql('pre_states',engine_write,index=False,if_exists='replace', schema='stardb')
df1246.to_sql('pre_survey_form',engine_write,index=False,if_exists='replace', schema='stardb')
df1247.to_sql('pre_taluk',engine_write,index=False,if_exists='replace', schema='stardb')
df1248.to_sql('pre_village',engine_write,index=False,if_exists='replace', schema='stardb')
df1249.to_sql('register',engine_write,index=False,if_exists='replace', schema='stardb')
df1250.to_sql('se_branches',engine_write,index=False,if_exists='replace', schema='stardb')
df1251.to_sql('se_designation',engine_write,index=False,if_exists='replace', schema='stardb')
df1252.to_sql('se_emp_roles',engine_write,index=False,if_exists='replace', schema='stardb')
df1253.to_sql('se_employees',engine_write,index=False,if_exists='replace', schema='stardb')
df1254.to_sql('seed_company_role',engine_write,index=False,if_exists='replace', schema='stardb')
df1255.to_sql('set_all_docs',engine_write,index=False,if_exists='replace', schema='stardb')
df1256.to_sql('set_attribute_values',engine_write,index=False,if_exists='replace', schema='stardb')
df1257.to_sql('set_attributes_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1258.to_sql('set_com_param_values',engine_write,index=False,if_exists='replace', schema='stardb')
df1259.to_sql('set_do_docs',engine_write,index=False,if_exists='replace', schema='stardb')
df1260.to_sql('set_do_docs_log',engine_write,index=False,if_exists='replace', schema='stardb')
df1261.to_sql('set_gmv_data',engine_write,index=False,if_exists='replace', schema='stardb')
df1262.to_sql('set_manage_stock',engine_write,index=False,if_exists='replace', schema='stardb')
df1263.to_sql('set_quality_params_toggles',engine_write,index=False,if_exists='replace', schema='stardb')
df1264.to_sql('set_settlement_logs',engine_write,index=False,if_exists='replace', schema='stardb')
df1265.to_sql('set_stock_grievance',engine_write,index=False,if_exists='replace', schema='stardb')
df1266.to_sql('set_taxes',engine_write,index=False,if_exists='replace', schema='stardb')
df1267.to_sql('set_trade_deductions',engine_write,index=False,if_exists='replace', schema='stardb')
df1268.to_sql('set_trade_info',engine_write,index=False,if_exists='replace', schema='stardb')
df1269.to_sql('set_truck_param_map',engine_write,index=False,if_exists='replace', schema='stardb')
df1270.to_sql('set_users_info',engine_write,index=False,if_exists='replace', schema='stardb')
df1271.to_sql('set_weight_breakup',engine_write,index=False,if_exists='replace', schema='stardb')
df1272.to_sql('st_admins',engine_write,index=False,if_exists='replace', schema='stardb')
df1273.to_sql('st_alliances',engine_write,index=False,if_exists='replace', schema='stardb')
df1274.to_sql('st_app_defaults',engine_write,index=False,if_exists='replace', schema='stardb')
df1275.to_sql('st_areas',engine_write,index=False,if_exists='replace', schema='stardb')
df1276.to_sql('st_auc_time_slots',engine_write,index=False,if_exists='replace', schema='stardb')
df1277.to_sql('st_bags',engine_write,index=False,if_exists='replace', schema='stardb')
df1278.to_sql('st_bid_logger',engine_write,index=False,if_exists='replace', schema='stardb')
df1279.to_sql('st_bsr',engine_write,index=False,if_exists='replace', schema='stardb')
df1280.to_sql('st_bsr_archive',engine_write,index=False,if_exists='replace', schema='stardb')
df1281.to_sql('st_bsr_mapping',engine_write,index=False,if_exists='replace', schema='stardb')
df1282.to_sql('st_buy_auctions',engine_write,index=False,if_exists='replace', schema='stardb')
df1283.to_sql('st_buy_orders',engine_write,index=False,if_exists='replace', schema='stardb')
df1284.to_sql('st_buyauc_com_params',engine_write,index=False,if_exists='replace', schema='stardb')
df1285.to_sql('st_buyeq_com_params',engine_write,index=False,if_exists='replace', schema='stardb')
df1286.to_sql('st_buyer_auction_bids',engine_write,index=False,if_exists='replace', schema='stardb')
df1287.to_sql('st_cis_cdf_entry',engine_write,index=False,if_exists='replace', schema='stardb')
df1288.to_sql('st_client_docs_mapping',engine_write,index=False,if_exists='replace', schema='stardb')
df1289.to_sql('st_client_registration',engine_write,index=False,if_exists='replace', schema='stardb')
df1290.to_sql('st_cms',engine_write,index=False,if_exists='replace', schema='stardb')
df1291.to_sql('st_com_deductions',engine_write,index=False,if_exists='replace', schema='stardb')
df1292.to_sql('st_com_mandi_price',engine_write,index=False,if_exists='replace', schema='stardb')
df1293.to_sql('st_com_params',engine_write,index=False,if_exists='replace', schema='stardb')
df1294.to_sql('st_commodities',engine_write,index=False,if_exists='replace', schema='stardb')
df1295.to_sql('st_company_users',engine_write,index=False,if_exists='replace', schema='stardb')
df1296.to_sql('st_content',engine_write,index=False,if_exists='replace', schema='stardb')
df1297.to_sql('st_directors',engine_write,index=False,if_exists='replace', schema='stardb')
df1298.to_sql('st_document_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1299.to_sql('st_employees',engine_write,index=False,if_exists='replace', schema='stardb')
df1300.to_sql('st_farmer_docs_mapping',engine_write,index=False,if_exists='replace', schema='stardb')
df1301.to_sql('st_farmer_registration',engine_write,index=False,if_exists='replace', schema='stardb')
df1302.to_sql('st_farmer_stock',engine_write,index=False,if_exists='replace', schema='stardb')
df1303.to_sql('st_firm_details',engine_write,index=False,if_exists='replace', schema='stardb')
df1304.to_sql('st_gst',engine_write,index=False,if_exists='replace', schema='stardb')
df1305.to_sql('st_inventory',engine_write,index=False,if_exists='replace', schema='stardb')
df1306.to_sql('st_labs',engine_write,index=False,if_exists='replace', schema='stardb')
df1307.to_sql('st_locations',engine_write,index=False,if_exists='replace', schema='stardb')
df1308.to_sql('st_mandis',engine_write,index=False,if_exists='replace', schema='stardb')
df1309.to_sql('st_notifications_users',engine_write,index=False,if_exists='replace', schema='stardb')
df1310.to_sql('st_offer_to_buy',engine_write,index=False,if_exists='replace', schema='stardb')
df1311.to_sql('st_offer_to_sell',engine_write,index=False,if_exists='replace', schema='stardb')
df1312.to_sql('st_offline_inventory',engine_write,index=False,if_exists='replace', schema='stardb')
df1313.to_sql('st_offline_inventory_archive',engine_write,index=False,if_exists='replace', schema='stardb')
df1314.to_sql('st_order_offers',engine_write,index=False,if_exists='replace', schema='stardb')
df1315.to_sql('st_order_types',engine_write,index=False,if_exists='replace', schema='stardb')
df1316.to_sql('st_pg_info',engine_write,index=False,if_exists='replace', schema='stardb')
df1317.to_sql('st_pg_transactions',engine_write,index=False,if_exists='replace', schema='stardb')
df1318.to_sql('st_pg_user_accounts',engine_write,index=False,if_exists='replace', schema='stardb')
df1319.to_sql('st_pg_user_accounts_old',engine_write,index=False,if_exists='replace', schema='stardb')
df1320.to_sql('st_pg_wallet',engine_write,index=False,if_exists='replace', schema='stardb')
df1321.to_sql('st_search_tag',engine_write,index=False,if_exists='replace', schema='stardb')
df1322.to_sql('st_sell_auctions',engine_write,index=False,if_exists='replace', schema='stardb')
df1323.to_sql('st_sell_orders',engine_write,index=False,if_exists='replace', schema='stardb')
df1324.to_sql('st_sellauc_com_params',engine_write,index=False,if_exists='replace', schema='stardb')
df1325.to_sql('st_selleq_com_params',engine_write,index=False,if_exists='replace', schema='stardb')
df1326.to_sql('st_seller_auction_bids',engine_write,index=False,if_exists='replace', schema='stardb')
df1327.to_sql('st_sms_text',engine_write,index=False,if_exists='replace', schema='stardb')
df1328.to_sql('st_states',engine_write,index=False,if_exists='replace', schema='stardb')
df1329.to_sql('st_stock_com_params',engine_write,index=False,if_exists='replace', schema='stardb')
df1330.to_sql('st_trade_chats',engine_write,index=False,if_exists='replace', schema='stardb')
df1331.to_sql('st_trade_docs_map',engine_write,index=False,if_exists='replace', schema='stardb')
df1332.to_sql('st_trade_docs_master',engine_write,index=False,if_exists='replace', schema='stardb')
df1333.to_sql('st_trade_shipments',engine_write,index=False,if_exists='replace', schema='stardb')
df1334.to_sql('st_trade_stages',engine_write,index=False,if_exists='replace', schema='stardb')
df1335.to_sql('st_trade_taxes',engine_write,index=False,if_exists='replace', schema='stardb')
df1336.to_sql('st_trade_trucks',engine_write,index=False,if_exists='replace', schema='stardb')
df1337.to_sql('st_trades',engine_write,index=False,if_exists='replace', schema='stardb')
df1338.to_sql('st_trades_transactions',engine_write,index=False,if_exists='replace', schema='stardb')
df1339.to_sql('st_transports',engine_write,index=False,if_exists='replace', schema='stardb')
df1340.to_sql('st_user_bank_accounts',engine_write,index=False,if_exists='replace', schema='stardb')
df1341.to_sql('st_user_bank_accounts_old',engine_write,index=False,if_exists='replace', schema='stardb')
df1342.to_sql('st_user_payment_log',engine_write,index=False,if_exists='replace', schema='stardb')
df1343.to_sql('st_users',engine_write,index=False,if_exists='replace', schema='stardb')
df1344.to_sql('st_users_old',engine_write,index=False,if_exists='replace', schema='stardb')
df1345.to_sql('st_warehouses',engine_write,index=False,if_exists='replace', schema='stardb')
df1346.to_sql('st_wr_sr_platform',engine_write,index=False,if_exists='replace', schema='stardb')
df1347.to_sql('unsubscribe_email',engine_write,index=False,if_exists='replace', schema='stardb')
df1348.to_sql('view_user_data_pvt',engine_write,index=False,if_exists='replace', schema='stardb')
