# %% [markdown]
# # Final ETL Script Privatedb

# %%
import pandas as pd
import sqlalchemy
from datetime import datetime

# %%
engine_write = sqlalchemy.create_engine('mysql+pymysql://manoj:cJtDsZ4UF6djRRXg@agri-reports.c2c32urb2pzx.ap-south-1.rds.amazonaws.com:3306/agri_reports')

# %%
engine_read = sqlalchemy.create_engine('mysql+pymysql://report:fa4SsPAwfDAKw4Nd@database-read-1.c2c32urb2pzx.ap-south-1.rds.amazonaws.com:3306/agribazaar')

# %%
df1 = pd.read_sql('delivery_orders',engine_read)
df2 = pd.read_sql('mandi_markets',engine_read)
df3 = pd.read_sql('photos',engine_read)
df4 = pd.read_sql('orders',engine_read)
df5 = pd.read_sql('tickets',engine_read)
df6 = pd.read_sql('mandi_commodities',engine_read)
df7 = pd.read_sql('city_pincodes',engine_read)
df8 = pd.read_sql('user_roles',engine_read)
df9 = pd.read_sql('trade_quality_parameters',engine_read)
df10 = pd.read_sql('units',engine_read)
df11 = pd.read_sql('e_kyc_responses',engine_read)
df12 = pd.read_sql('states',engine_read)
df13 = pd.read_sql('mandibhavs',engine_read)
df14 = pd.read_sql('notification_lists',engine_read)
df15 = pd.read_sql('grievances',engine_read)
df16 = pd.read_sql('tolerance_and_deductions',engine_read)
df17 = pd.read_sql('app_clients',engine_read)
df18 = pd.read_sql('customers',engine_read)
df19 = pd.read_sql('schema_migrations',engine_read)
df20 = pd.read_sql('addresses',engine_read)
df21 = pd.read_sql('leads',engine_read)
df22 = pd.read_sql('devices',engine_read)
df23 = pd.read_sql('unit_converters',engine_read)
df24 = pd.read_sql('active_storage_blobs',engine_read)
df25 = pd.read_sql('postalcode_rules',engine_read)
df26 = pd.read_sql('preferred_commodities',engine_read)
df27 = pd.read_sql('roles',engine_read)
df28 = pd.read_sql('sms_template_masters',engine_read)
df29 = pd.read_sql('commodity_quality_parameters',engine_read)
df30 = pd.read_sql('commodity_groups',engine_read)
df31 = pd.read_sql('documents',engine_read)
df32 = pd.read_sql('bid_counter_offers',engine_read)
df33 = pd.read_sql('delivery_and_payment_timelines',engine_read)
df34 = pd.read_sql('notification_template_masters',engine_read)
df35 = pd.read_sql('trades',engine_read)
df36 = pd.read_sql('data_trackers',engine_read)
df37 = pd.read_sql('ar_internal_metadata',engine_read)
df38 = pd.read_sql('delivery_order_acceptance_quality_parameters',engine_read)
df39 = pd.read_sql('sequences',engine_read)
df40 = pd.read_sql('delivery_order_settelment_details',engine_read)
df41 = pd.read_sql('transaction_logs',engine_read)
df42 = pd.read_sql('backoffice_users',engine_read)
df43 = pd.read_sql('gst_infos',engine_read)
df44 = pd.read_sql('active_storage_variant_records',engine_read)
df45 = pd.read_sql('commodities',engine_read)
df46 = pd.read_sql('organizations',engine_read)
df47 = pd.read_sql('bids',engine_read)
df48 = pd.read_sql('districts',engine_read)
df49 = pd.read_sql('active_storage_attachments',engine_read)
df50 = pd.read_sql('quality_params',engine_read)
df51 = pd.read_sql('payments',engine_read)
df52 = pd.read_sql('mobile_verifications',engine_read)
df53 = pd.read_sql('govt_db_user_updates',engine_read)

# %%
start_time = datetime.now()
print('Data transfer start...')
print('Loading table... delivery_orders')
df1.to_sql('delivery_orders',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... mandi_markets')
df2.to_sql('mandi_markets',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... photos')
df3.to_sql('photos',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... orders')
df4.to_sql('orders',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... tickets')
df5.to_sql('tickets',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... mandi_commodities')
df6.to_sql('mandi_commodities',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... city_pincodes')
df7.to_sql('city_pincodes',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... user_roles')
df8.to_sql('user_roles',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... trade_quality_parameters')
df9.to_sql('trade_quality_parameters',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... units')
df10.to_sql('units',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... e_kyc_responses')
df11.to_sql('e_kyc_responses',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... states')
df12.to_sql('states',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... mandibhavs')
df13.to_sql('mandibhavs',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... notification_lists')
df14.to_sql('notification_lists',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... grievances')
df15.to_sql('grievances',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... tolerance_and_deductions')
df16.to_sql('tolerance_and_deductions',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... app_clients')
df17.to_sql('app_clients',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... customers')
df18.to_sql('customers',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... schema_migrations')
df19.to_sql('schema_migrations',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... addresses')
df20.to_sql('addresses',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... leads')
df21.to_sql('leads',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... devices')
df22.to_sql('devices',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... unit_converters')
df23.to_sql('unit_converters',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... active_storage_blobs')
df24.to_sql('active_storage_blobs',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... postalcode_rules')
df25.to_sql('postalcode_rules',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... preferred_commodities')
df26.to_sql('preferred_commodities',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... roles')
df27.to_sql('roles',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... sms_template_masters')
df28.to_sql('sms_template_masters',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... commodity_quality_parameters')
df29.to_sql('commodity_quality_parameters',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... commodity_groups')
df30.to_sql('commodity_groups',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... documents')
df31.to_sql('documents',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... bid_counter_offers')
df32.to_sql('bid_counter_offers',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... delivery_and_payment_timelines')
df33.to_sql('delivery_and_payment_timelines',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... notification_template_masters')
df34.to_sql('notification_template_masters',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... trades')
df35.to_sql('trades',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... data_trackers')
df36.to_sql('data_trackers',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... ar_internal_metadata')
df37.to_sql('ar_internal_metadata',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... delivery_order_acceptance_quality_parameters')
df38.to_sql('delivery_order_acceptance_quality_parameters',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... sequences')
df39.to_sql('sequences',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... delivery_order_settlement_details')
df40.to_sql('delivery_order_settelment_details',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... transaction_logs')
df41.to_sql('transaction_logs',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... backoffice_users')
df42.to_sql('backoffice_users',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... gst_infos')
df43.to_sql('gst_infos',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... active_storage_variant_records')
df44.to_sql('active_storage_variant_records',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... commodities')
df45.to_sql('commodities',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... organizations')
df46.to_sql('organizations',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... bids')
df47.to_sql('bids',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... districts')
df48.to_sql('districts',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... active_storage_attachments')
df49.to_sql('active_storage_attachments',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... quality_params')
df50.to_sql('quality_params',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... payments')
df51.to_sql('payments',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... mobile_varifications')
df52.to_sql('mobile_verifications',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\n')

start_time = datetime.now()
print('Loading table... govt_db_user_updates')
df53.to_sql('govt_db_user_updates',engine_write,index=False,if_exists='replace', schema='private_db')
time_to_load = (datetime.now() - start_time).seconds
print(time_to_load,'Sec\nTransfer completed !!')
